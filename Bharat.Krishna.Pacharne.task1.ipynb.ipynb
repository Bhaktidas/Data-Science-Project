# %% [markdown]
# ● Import the dataset, convert the target variable values to 0 and 1, separate features from target values.
#
# ● Split the features into numeric and categorical datasets.
#
# ● Run descriptive statistical analysis on numerical features

# %%
#importing required libraries 
import pandas as pd
import numpy as np

# %%
ideaspice_df = pd.read_csv('/content/ideaspiceemployeeturnoverdatset.csv')

# %%
ideaspice_df.head()
# Out:
#    EmployeId  Age Gender MaritalStatus Turnover Travelling  \
# 0         63   29      M      Divorced       No  Sometimes
# 1        723   23      M        Single       No     Mostly
# 2       1297   36      M        Single      Yes  Sometimes
# 3         51   30      M      Divorced       No  Sometimes
# 4       1498   29      M        Single      Yes  Sometimes
#
#                  Vertical  Qualifications    EducationField  \
# 0  Research & Development               1           Medical
# 1                   Sales               1     Life Sciences
# 2         Human Resources               4     Life Sciences
# 3  Research & Development               4           Medical
# 4                   Sales               3  Technical Degree
#
#    EmployeSatisfaction  ...  RelationshipSatisfaction  Hours  \
# 0                    3  ...                         4     80
# 1                    2  ...                         4     80
# ...

# %%
ideaspice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeId                 1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Gender                    1470 non-null   object
#  3   MaritalStatus             1470 non-null   object
#  4   Turnover                  1470 non-null   object
#  5   Travelling                1470 non-null   object
#  6   Vertical                  1470 non-null   object
#  7   Qualifications            1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeSatisfaction       1470 non-null   int64
#  10  JobEngagement             1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobSatisfaction           1470 non-null   int64
#  13  Role                      1470 non-null   object
# ...

# %% [markdown]
# convert the target variable values to 0 and 1, separate features from target values.

# %%
ideaspice_df['Turnover'].describe() # there are no null values in our target variable
# Out:
# count     1470
# unique       2
# top         No
# freq      1203
# Name: Turnover, dtype: object

# %%
from sklearn import preprocessing 
ideaspice_df_2 = preprocessing.LabelEncoder()
ideaspice_df['Turnover']=ideaspice_df_2.fit_transform(ideaspice_df['Turnover'])

# %%
ideaspice_df['Turnover'].head(6)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# Name: Turnover, dtype: int64

# %%
ideaspice_df.head()
# Out:
#    EmployeId  Age Gender MaritalStatus  Turnover Travelling  \
# 0         63   29      M      Divorced         0  Sometimes
# 1        723   23      M        Single         0     Mostly
# 2       1297   36      M        Single         1  Sometimes
# 3         51   30      M      Divorced         0  Sometimes
# 4       1498   29      M        Single         1  Sometimes
#
#                  Vertical  Qualifications    EducationField  \
# 0  Research & Development               1           Medical
# 1                   Sales               1     Life Sciences
# 2         Human Resources               4     Life Sciences
# 3  Research & Development               4           Medical
# 4                   Sales               3  Technical Degree
#
#    EmployeSatisfaction  ...  RelationshipSatisfaction  Hours  \
# 0                    3  ...                         4     80
# 1                    2  ...                         4     80
# ...

# %%
target = ideaspice_df.pop('Turnover')

# %%
features = ideaspice_df

# %%
ideaspice_df.columns
# Out:
# Index(['EmployeId', 'Age', 'Gender', 'MaritalStatus', 'Travelling', 'Vertical',
#        'Qualifications', 'EducationField', 'EmployeSatisfaction',
#        'JobEngagement', 'JobLevel', 'JobSatisfaction', 'Role', 'DailyBilling',
#        'HourBilling', 'MonthlyBilling', 'MonthlyRate', 'Work Experience',
#        'OverTime', 'PercentSalaryHike', 'Last Rating',
#        'RelationshipSatisfaction', 'Hours', 'StockOptionLevel',
#        'TrainingTimesLastYear', 'Work&Life', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrentManager', 'DistanceFromHome'],
#       dtype='object')

# %%
target.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Turnover, dtype: int64

# %%
features.head()
# Out:
#    EmployeId  Age Gender MaritalStatus Travelling                Vertical  \
# 0         63   29      M      Divorced  Sometimes  Research & Development
# 1        723   23      M        Single     Mostly                   Sales
# 2       1297   36      M        Single  Sometimes         Human Resources
# 3         51   30      M      Divorced  Sometimes  Research & Development
# 4       1498   29      M        Single  Sometimes                   Sales
#
#    Qualifications    EducationField  EmployeSatisfaction  JobEngagement  ...  \
# 0               1           Medical                    3              3  ...
# 1               1     Life Sciences                    2              3  ...
# 2               4     Life Sciences                    2              3  ...
# 3               4           Medical                    3              3  ...
# 4               3  Technical Degree                    4              3  ...
#
# ...

# %%
numeric_data = ideaspice_df.select_dtypes(include=[np.number])
categorical_data = ideaspice_df.select_dtypes(exclude=[np.number])

# %%
numeric_data.head(3)
# Out:
#    EmployeId  Age  Qualifications  EmployeSatisfaction  JobEngagement  \
# 0         63   29               1                    3              3
# 1        723   23               1                    2              3
# 2       1297   36               4                    2              3
#
#    JobLevel  JobSatisfaction  DailyBilling  HourBilling  MonthlyBilling  ...  \
# 0         1                1           368           37            7062  ...
# 1         1                3           599           97            2036  ...
# 2         2                4           833           34            6052  ...
#
#    RelationshipSatisfaction  Hours  StockOptionLevel  TrainingTimesLastYear  \
# 0                         4     80                 1                      2
# 1                         4     80                 0                      3
# 2                         3     80                 0                      3
#
# ...

# %%
numeric_data.shape
# there are 24 numerial columns
# Out:
# (1470, 24)

# %%
categorical_data.head(3)
# Out:
#   Gender MaritalStatus Travelling                Vertical EducationField  \
# 0      M      Divorced  Sometimes  Research & Development        Medical
# 1      M        Single     Mostly                   Sales  Life Sciences
# 2      M        Single  Sometimes         Human Resources  Life Sciences
#
#                     Role OverTime
# 0  Laboratory Technician       No
# 1   Sales Representative       No
# 2                Manager       No

# %%
categorical_data.shape
# there are 7 categorical columns
# Out:
# (1470, 7)

# %% [markdown]
# Run descriptive statistical analysis on numerical features

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeId                 1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Qualifications            1470 non-null   int64
#  3   EmployeSatisfaction       1470 non-null   int64
#  4   JobEngagement             1470 non-null   int64
#  5   JobLevel                  1470 non-null   int64
#  6   JobSatisfaction           1470 non-null   int64
#  7   DailyBilling              1470 non-null   int64
#  8   HourBilling               1470 non-null   int64
#  9   MonthlyBilling            1470 non-null   int64
#  10  MonthlyRate               1470 non-null   int64
#  11  Work Experience           1470 non-null   int64
#  12  PercentSalaryHike         1470 non-null   int64
#  13  Last Rating               1470 non-null   int64
# ...

# %%
numeric_data.describe()
# Out:
#          EmployeId          Age  Qualifications  EmployeSatisfaction  \
# count  1470.000000  1470.000000     1470.000000          1470.000000
# mean   1056.771429    37.065306        2.876190             2.702041
# std     594.598084     9.522562        1.019038             1.095039
# min       8.000000    18.000000        1.000000             1.000000
# 25%     531.250000    30.000000        2.000000             2.000000
# 50%    1073.000000    36.000000        3.000000             3.000000
# 75%    1553.750000    44.000000        4.000000             4.000000
# max    2060.000000    59.000000        5.000000             4.000000
#
#        JobEngagement     JobLevel  JobSatisfaction  DailyBilling  HourBilling  \
# count    1470.000000  1470.000000      1470.000000   1470.000000  1470.000000
# mean        2.712245     2.087075         2.785034    763.046939    65.074830
# std         0.731141     1.109663         1.095840    426.331994    20.604377
# ...

# %%
import sweetviz as sv

# %%
#EDA using Autoviz
sweet_report = sv.analyze(numeric_data)

#Saving results to HTML file
sweet_report.show_html('sweet_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
